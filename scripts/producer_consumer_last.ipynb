# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("IPL-Batch-Analytics") \
    .getOrCreate()

# %%
# to check,how amny matches are done after stopping the producer and consumer code.
spark.read.parquet("hdfs:///ipl/streaming/runs_per_match")\
.orderBy("match_id")\
.show(20, False)
# Out:
# +--------+---------------+
# |match_id|live_total_runs|
# +--------+---------------+
# |335982  |518            |
# |335983  |447            |
# |335984  |261            |
# |335985  |399            |
# |335986  |333            |
# |335987  |334            |
# |335988  |285            |
# |335989  |234            |
# +--------+---------------+

# %%
##   hdfs dfs -ls /ipl/streaming/runs_per_match

# %%
# Copy and paste this version, or re-type the path line
spark.read.parquet("hdfs:///ipl/streaming/runs_per_match") \
    .coalesce(1) \
    .write \
    .mode("overwrite") \
    .option("header", "true") \
    .csv("hdfs:///ipl/exports_csv/rt_runs_per_match")
